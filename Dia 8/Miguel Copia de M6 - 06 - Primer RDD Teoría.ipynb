# %% [markdown]
# #  RDDs

# %% [markdown]
# # Creamos un contexto para crear RDDs

# %%
# !pip install pyspark --quiet
from pyspark import SparkContext

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5c6b4d5d9db0> in <cell line: 1>()
# ----> 1 spark.stop()
#
# NameError: name 'spark' is not defined

# %%
sc = SparkContext(master = "local", appName="TransformacionesyAcciones")

# %% [markdown]
# # Un RDD es una colección inmutable y distribuida de elementos
#
# ### Spark automaticamente distribuye los datos y paraleliza las operaciones
#
# ### Los RDD realmente cargan colecciones de datos

# %%
rdd1 = sc.parallelize([1,2,3])

# %% [markdown]
# ### Debido a la propiedad de distribución que tienen los RDD, en su creación, podemos particionar los datos

# %%
import numpy as np
rdd2 = sc.parallelize(np.array(range(100)),2)

# %% [markdown]
# ### Verificamos el tipo de dato

# %%
type(rdd1)
# Out:
# pyspark.rdd.RDD

# %% [markdown]
# ### Vemos el contenido
#
# Veremos distintas tecnicas apropiadas para ver el contenido de los RDDs y Dataframes

# %%
rdd1.collect()
# Out:
# [1, 2, 3]

# %% [markdown]
# # Carga de un arhivo CSV

# %% [markdown]
# ### Cargamos un RDDs
#
# El método textFile busca el archivo en la ruta indicada
#
# Cambia el valor de la ruta para que apunte a la ruta donde tienes los datos

# %%
from google.colab import drive
drive.mount('/content/drive/')

equiposOlimpicosRDD = sc.textFile("/content/drive/MyDrive/Cole/Semana Online/CSV/paises.csv",2).map(lambda line : line.split(","))
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### Vemos el contenido
#
# El método take es otro método existnte para poder visualizar el contenido de los RDDs

# %%
equiposOlimpicosRDD.take(10)
# Out:
# [['id', 'equipo', 'sigla'],
#  ['1', '30. Februar', 'AUT'],
#  ['2', 'A North American Team', 'MEX'],
#  ['3', 'Acipactli', 'MEX'],
#  ['4', 'Acturus', 'ARG'],
#  ['5', 'Afghanistan', 'AFG'],
#  ['6', 'Akatonbo', 'IRL'],
#  ['7', 'Alain IV', 'SUI'],
#  ['8', 'Albania', 'ALB'],
#  ['9', 'Alcaid', 'POR']]

# %%
sc.stop()

# %% [markdown]
# ## Ejercicio:
#
# Intenta leer un archivo csv o de texto y hacer alguna transformación.
#
# * Busca el archivo del quijote.txt por internet.
# * Subelo a Google COlab e importalo con pyspark.
# * Cuenta los caracteres del fichero.

# %%
#Inserta aquí tú código
quijoteRDD =sc.textFile("/content/el_quijote.txt",2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-4d9fb365d48a> in <cell line: 2>()
#       1 #Inserta aquí tú código
# ----> 2 quijoteRDD =sc.textFile("/content/el_quijote.txt",2)
#
# /usr/local/lib/python3.10/dist-packages/pyspark/context.py in textFile(self, name, minPartitions, use_unicode)
#     988         """
#     989         minPartitions = minPartitions or min(self.defaultParallelism, 2)
# --> 990         return RDD(self._jsc.textFile(name, minPartitions), self, UTF8Deserializer(use_unicode))
#     991
#     992     def wholeTextFiles(
#
# AttributeError: 'NoneType' object has no attribute 'textFile'
